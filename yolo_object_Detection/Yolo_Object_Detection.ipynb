# %%
# !unzip /content/drive/MyDrive/images.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/images.zip
#    creating: /content/images/
#   inflating: /content/images/cam_image5.txt
#   inflating: /content/images/IMG_2561.JPG
#   inflating: /content/__MACOSX/images/._IMG_2561.JPG
#   inflating: /content/images/IMG_2463.txt
#   inflating: /content/images/IMG_2476.txt
#   inflating: /content/images/IMG_2560.JPG
#   inflating: /content/__MACOSX/images/._IMG_2560.JPG
#   inflating: /content/images/cam_image4.txt
#   inflating: /content/images/classes.txt
#   inflating: /content/images/cam_image6.txt
#   inflating: /content/images/IMG_2461.txt
#   inflating: /content/images/IMG_2403.JPG
#   inflating: /content/__MACOSX/images/._IMG_2403.JPG
#   inflating: /content/images/cam_image7.txt
#   inflating: /content/images/IMG_2539.txt
#   inflating: /content/images/.DS_Store
#   inflating: /content/__MACOSX/images/._.DS_Store
#   inflating: /content/images/IMG_2470.txt
#   inflating: /content/images/cam_image2.txt
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.04 MiB | 17.93 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
ls
# Out:
# 3rdparty/               darknet_video.py        net_cam_v4.sh*
# build/                  data/                   README.md
# build.ps1*              image_yolov3.sh*        results/
# cfg/                    image_yolov4.sh*        scripts/
# cmake/                  include/                src/
# CMakeLists.txt          json_mjpeg_streams.sh*  vcpkg.json
# DarknetConfig.cmake.in  LICENSE                 video_yolov3.sh*
# darknet_images.py       Makefile                video_yolov4.sh*
# darknet.py              net_cam_v3.sh*

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !python /content/creating-train-and-test-txt-files.py

# %%
# !python /content/creating-files-data-and-name.py

# %%
#Checking the compilation
# !/content/darknet/darknet
# Out:
# usage: /content/darknet/darknet <function>

# %%
# !/content/darknet/darknet detector train /content/images/labelled_data.data  /content/darknet/cfg/yolov3.cfg  /content/drive/MyDrive/custom_weight/darknet53.conv.74  -dont_show
