# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-January/blob/main/Logistic%20Regression/Assignment_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import some important library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from mlxtend.plotting import plot_decision_regions
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# #**Excercise**

# %% [markdown]
# In the excercise Your task is first fit the the data into Logistic Regression and predict accuracy if you are not getting good score then do  some EDA and improve your accuracy.

# %% [markdown]
# #First

# %%
x1 = np.linspace(-1, 1, 200)
x2 = np.concatenate([np.random.permutation(np.linspace(-1, 0, 100)), np.random.permutation(np.linspace(0, 1 , 100))])

y = np.where(x1 >= 0, 0, 1)

# %%
plt.scatter(x1, x2, c=y)

# %%
X = np.dstack([x1, x2])[0]

# %%
log = LogisticRegression()
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
plot_decision_regions(X, y, clf = log)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %% [markdown]
# #2nd

# %%
from sklearn.datasets import make_circles
X, y = make_circles(n_samples = 500, noise =0.05, factor = 0.5)
x1, x2 = X[:, 0], X[:, 1]
plt.scatter(x1, x2, c=y)

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X), y)
# Out:
# 0.506

# %% [markdown]
# we are getting 50 percent of accuracy and we can see the data is not linearly seprable so we have to do some feature engineering.

# %%
plt.scatter(x1, x2, c = log.predict(X))

# %%
X = np.hstack([(x1*x1).reshape(-1, 1), (x2*x2).reshape(-1,1)])

# %%
x1, x2 = X[:, 0], X[:, 1]

# %%
plt.scatter(x1, x2, c=y)

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X), y)
# Out:
# 1.0

# %%
plt.scatter(x1, x2, c = log.predict(X))

# %% [markdown]
# #3rd

# %%
x1 = np.linspace(-1,1, 200)
x2 = np.random.permutation(np.linspace(-1, 1, 200))

y = np.where(x1*x2 >= 0, 0, 1)

# %%
plt.scatter(x1, x2, c=y)

# %%
X = np.dstack([x1, x2])[0]
X.shape
# Out:
# (200, 2)

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X), y)
# Out:
# 0.52

# %%
plt.scatter(x1, x2, c= log.predict(X))

# %%
plot_decision_regions(X, y, clf = log)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
X.shape
# Out:
# (200, 2)

# %%
X = (x1*x2).reshape(-1, 1)

# %%
X.shape
# Out:
# (200, 1)

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X),y)
# Out:
# 0.93

# %%
plt.scatter(x1, x2, c = log.predict(X))

# %%
plot_decision_regions(X, y, clf=log)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
plt.scatter(x1, x2, color = np.where(log.predict(X)==y, 'g', 'r'))

# %% [markdown]
# #4th

# %%
x1 = np.linspace(-380, 369, 360*2)
x2 = np.sin(np.deg2rad(x1))+0.2

# %%
x2[::2] += -0.5
y = np.zeros(x1.size, dtype='int8')
y[::2] = 1

plt.scatter(x1, x2, c=y)

# %%
X = np.dstack([x1, x2])[0]

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X), y)
# Out:
# 0.5986111111111111

# %%
plt.scatter(x1, x2, c=log.predict(X))

# %%
plot_decision_regions(X, y, clf = log)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
X = np.dstack([
    np.sin(np.deg2rad(x1)),
    np.sin(np.deg2rad(x2)),
])[0]

# %%
X.shape
# Out:
# (720, 2)

# %%
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
accuracy_score(log.predict(X), y)
# Out:
# 1.0

# %%
plt.scatter(x1, x2, c=log.predict(X))

# %%
plt.scatter(X[:, 0], X[:, 1], c=log.predict(X))

# %% [markdown]
# #Project

# %%
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')
df.sample(7)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 738            2       99  ...   21        0
# 541            3      128  ...   27        1
# 444            4      117  ...   30        1
# 284            2      108  ...   52        1
# 200            0      113  ...   21        0
# 635           13      104  ...   38        1
# 368            3       81  ...   22        0
#
# [7 rows x 9 columns]

# %% [markdown]
# Pregnancies: Number of times pregnant
#
# Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# BloodPressure: Diastolic blood pressure (mm Hg)
#
# SkinThickness: Triceps skin fold thickness (mm)
#
# Insulin: 2-Hour serum insulin (mu U/ml)
#
# BMI: Body mass index (weight in kg/(height in m)^2)
#
# DiabetesPedigreeFunction: Diabetes pedigree function
#
# Age: Age (years)
#
# Outcome: Class variable ( 0 - 1)

# %% [markdown]
# #Data cleaning and Data Prepration
# In this step we find missing value

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# **0 entries in BMI, Blood Pressure,Glucose, Skin Thickness and Insulin**

# %%
for col in ['BloodPressure', 'Glucose', 'SkinThickness','Insulin', 'BMI']:
  sns.distplot(df[col])
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %% [markdown]
# All seems like having **Normal Distribution** filling **media** values.

# %%
for col in ['BloodPressure', 'Glucose', 'SkinThickness','Insulin', 'BMI']:
  df[col] = df[col].replace(to_replace=0, value=df[col].median())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  121.656250  ...   33.240885    0.348958
# std       3.369578   30.438286  ...   11.760232    0.476951
# min       0.000000   44.000000  ...   21.000000    0.000000
# 25%       1.000000   99.750000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# #Data Visualisation

# %%
sns.countplot(df['Outcome'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(df['Pregnancies'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(data=df, x='Pregnancies', hue='Outcome')

# %%
sns.boxplot(x='Outcome', y='Age', data=df, palette='rainbow')

# %%
sns.boxplot(x='Outcome', y='Glucose', data=df, palette='rainbow')

# %%
sns.barplot(df['Outcome'], df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.distplot(df[df['Outcome']==0]['Age'], hist = False)
sns.distplot(df[df['Outcome']==1]['Age'], hist = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).

# %%
(df.groupby('Pregnancies')['Outcome'].mean()*100).plot(kind='bar')

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
for col in df.columns:
  sns.histplot(df[col], kde=True)
  plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.boxplot(data=df)

# %%
for col in df.columns:
  px.box(df, y=col, color='Outcome').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ccf2d7a4-d606-4e16-bbb1-e6fec5e24c8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ccf2d7a4-d606-4e16-bbb1-e6fec5e24c8d")) {
#                     Plotly.newPlot(
#                         'ccf2d7a4-d606-4e16-bbb1-e6fec5e24c8d',
# ...

# %%
sns.countplot(data=df, x='Pregnancies', hue='Outcome')

# %%
(df.groupby('Pregnancies').mean()['Outcome']).plot(kind='bar')

# %%
df['Pregnancies'] = np.where(df['Pregnancies']>=6, 0, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 54.1 KB

# %% [markdown]
# #Feature Engineering

# %%
def set_bmi(row):
    if row < 18.5:
        return "Under"
    elif row <= 24.9:
        return "Healthy"
    elif row <= 29.9:
        return "Over"
    elif row >= 30:
        return "Obese"

df['BMI_STAT'] = df["BMI"].apply(set_bmi)

# %%
sns.countplot(data=df, x='BMI_STAT', hue='Outcome')

# %%
def set_insulin(row):
    if row >= 16 and row <= 166:
        return "Normal"
    else:
        return "Abnormal"

df['Insulin_STAT'] = df['Insulin'].apply(set_insulin)

sns.countplot(data=df, x='Insulin_STAT', hue='Outcome')

# %%
df.corr()['Outcome'].sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.492782
# BMI                         0.312249
# Age                         0.238356
# SkinThickness               0.189065
# DiabetesPedigreeFunction    0.173844
# BloodPressure               0.165723
# Insulin                     0.148457
# Pregnancies                -0.209219
# Name: Outcome, dtype: float64

# %%
df['Pregnancies_STAT'] = np.where(df['Pregnancies'] <= 6,0,1)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'BMI_STAT',
#        'Insulin_STAT', 'Pregnancies_STAT'],
#       dtype='object')

# %%
df1 = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']]

df2 = df[['Glucose', 'BloodPressure', 'SkinThickness',
           'DiabetesPedigreeFunction', 'Age', 'Outcome',
          'BMI_STAT', 'Insulin_STAT', 'Pregnancies']]

# %%
df2 = df2.join(pd.get_dummies(df2[['BMI_STAT', 'Insulin_STAT']], drop_first=True))
df2.drop(['BMI_STAT', 'Insulin_STAT'], axis = 1, inplace = True)
df2.sample(4)
# Out:
#      Glucose  BloodPressure  ...  BMI_STAT_Under  Insulin_STAT_Normal
# 438       97             70  ...               1                    1
# 71       139             64  ...               0                    1
# 119       99             76  ...               0                    1
# 244      146             76  ...               0                    0
#
# [4 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
df_train = df2
X = df_train.drop(['Outcome'], axis=1)
y = df_train['Outcome']

X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split 
xtrain, xtest , ytrain , ytest = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression

log = LogisticRegression()
log.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
log.score(xtest, ytest)
# Out:
# 0.8311688311688312

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': np.linspace(0.0, 1.5, 20), 'penalty':['l1', 'l2','elastic','none']}
grid = GridSearchCV(log, param_grid, cv=10)
grid.fit(xtrain, ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:811: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:122: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:127: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:811: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:122: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:127: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:811: RuntimeWarning:
#
# ...

# %%
grid.best_score_, grid.best_params_
# Out:
# (0.7735060814383924, {'C': 0.0, 'penalty': 'none'})
