# %% [markdown]
# <a href="https://colab.research.google.com/github/aman5898/Data-Science-January/blob/main/Ploting/Ploting_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In this NoteBook We will cover Data Visualization Part
#
# * We will see How many types of graph and how we can Visualize them.
# * Note : In this note book we are going to see commonly used plotting technique, You are free to explore many more other ploting technique.

# %% [markdown]
# **Different Types of Analysis**
#
# *  Univariate(U) : In univariate analysis we will be using a single feature to analyze most of its properties.
#
# *  Bivariate(B) : When we compare the data between exactly 2 features then its called bivariate analysis.
#
# *  Multivariate(M): Comparing more than 2 variables is called as Multivariate analysis.

# %% [markdown]
# **these are some of the terms You have to know in Ploting**
# *  Grid
# *  Legend
# *  subplot
# *  Title
# *  xlabel
# *  ylabel

# %% [markdown]
# #Dataset 1
# * This is a (synthetic) dataset of insurance charges, we will see if we can understand why some customers pay more than others.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('https://media.githubusercontent.com/media/Ramanand-Yadav/DatasetForDataScience/main/Medical_Cost.csv')

# %%
# print rows in the dataset
??
# print columns in the dataset
??
# print columns of the dataset into a list 
??
# print sum of the values of the dataset 
??
# print all unique values for every feature (columns)
??
# a lookup of dataset
??

# %%
# Out:
# rows :  1338
# columns  :  7
# Features :
#  :  ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
# missing values :  0
# unique values :
#
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# #**Univariate Analysis**

# %% [markdown]
# ## **Categorical Feature**
# * countplot, piechart

# %% [markdown]
# **count plot method is used to Show the counts of observations in each categorical bin using bars**

# %%
# print all region wise values 
??

# %%
# Out:
# southeast    364
# northwest    325
# northeast    324
# southwest    325
# Name: region, dtype: int64

# %%
# print these value using dataframe.region.value_counts().index
??

# %%
# Out:
# Index(['southeast', 'southwest', 'northwest', 'northeast'], dtype='object')

# %% [markdown]
# Here you have to print countplot using multiple ways.

# %%
# using seaborn library plot simple countplot 
??

# in the below cell uncomment one by one line code and explore more about countplot

# %%
#region, smoker  children sex are the categorical feature 

# run every row and explore all parameters of countplot and do for every categorical feature 

# sns.countplot(df['region'])
# sns.countplot(x='region', data=df)
# sns.countplot(y='region', data=df)
# sns.countplot(data =df, x='region', palette="Set1")
# sns.countplot(x='region', data=df, order=df.region.value_counts().index) 
# sns.countplot(x='region', data=df, lw=4, ec='black',hatch='*')

# %% [markdown]
# we can see region wise contribution in the dataset.

# %% [markdown]
# **A pie chart (or a circle chart) is a circular statistical graphic, which is divided into slices to illustrate numerical proportion**

# %%
# pie plot 
??

# %% [markdown]
# parcentage contribution of every region

# %%
# use countplot for smoker 
sns.set_style('darkgrid')
??
??

# %%
# Out:
# Text(0.5, 1.0, 'smoker')

# %% [markdown]
# have you get any inside from above plot write here :

# %%
??

# %% [markdown]
# Inside :

# %%
# similar plot 
??
??
??

# %%
# Out:
# Text(0.5, 1.0, 'children')

# %% [markdown]
# Ans :

# %%
??

# %% [markdown]
# ## **Numerical**
# * Histgram
# * Distplot
# * Boxplot
#
# age, bmi, charges

# %% [markdown]
# **A histgram is a graphical representation that organizes a group of data points into user-specified ranges.**

# %%
# plot a histgram
sns.set_style('darkgrid')
??
??


# after completing this cell, go to next cell and run one by one to explore more about hist plot

# %%
sns.set_style('darkgrid')

# plt.hist(df['bmi'])
sns.histplot(x = 'bmi', data = df)
# sns.histplot(x='bmi', data=df,kde=True)
# (some more parameters you can try bins, binswidth, etc)
# sns.histplot(x='bmi', data=df, stat = 'density')
# sns.histplot(x='bmi', data=df, stat='probability', fill=False)
# sns.histplot(x='bmi', data=df, stat='probability', fill=False, element = 'step')
plt.title('BMI')
# Out:
# Text(0.5, 1.0, 'BMI')

# %% [markdown]
# using hist plot on numerical feature we can catigorize the values.

# %% [markdown]
# **A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables.**

# %%
# plot distplot for bmi feature(columns)
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'BMI Data Distribution')

# %% [markdown]
# using distplot on numerical feature we can see the distribution of the data.

# %% [markdown]
# **Boxplot is the type of plot that can be used to obtain more of the statistical details about the data. The straight lines at the maximum and minimum are also called as whiskers. Points outside of whiskers will be inferred as an outliers. The box plot gives us a representation of 25th, 50th ,75th quartiles.**

# %%
# boxplot
sns.set_style('white')
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Boxplot on BMI Feature')

# %%
# his plot on age feature
sns.set_style('darkgrid')
??
??
??

# %%
# Out:
# Text(0.5, 0, 'age')

# %%
# age
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'age')

# %%
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'age')

# %% [markdown]
# #**Bivariate & Multivariate Analysis**
# * (Numerical - Numerical)
# * (Numerical - Categorical)
# * (Categorical - Categorical)

# %% [markdown]
# ##Numerical vs Numerical
#
#
#
# *   Scatter

# %% [markdown]
# **scatter plot gives us a representation of where each points in the entire dataset are present with respect to any features(Columns). Scatter plots are available in 2D as well as 3D.**

# %%
# scatter plot on BMI and charges feature(columns)
??
??
??

# try out scatter plot form the given below cell

# %%
# Numerical vs Numircal
# sns.scatterplot(df['bmi'], df['charges'])
# plt.title('bmi vs charges')

# sns.scatterplot(x='bmi', y='charges', data =df)
# plt.title('BMI vs CHARGES')
# plt.xlabel('bmi')
# plt.ylabel('charges')

# scatter plot provide styel, size, hue and many more parameters. let's use these parameter also.
# Out:
# Text(0, 0.5, 'charges')

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to sns.regplot.

# %%
# to see the strength of relationship plot a regplot
??
??
??

# %%
# sns.regplot(x=df['bmi'], y=df['charges'])
# sns.regplot(x='bmi', y='charges', data = df)
# plt.title('reg plot bmi vs charges')
# plt.xlabel('bmi')
# plt.ylabel('charges')
# Out:
# Text(0, 0.5, 'charges')

# %%
# use hue paramater
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %% [markdown]
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.

# %% [markdown]
# **let's draw scatter plot age vs charges columns**

# %%
# scatter plot for age and charges
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %% [markdown]
# we can see if age is increases the charges is also increases.

# %%
# use some parameter of scater plot
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %% [markdown]
# ##Numerical vs Categorical
# * BarPlot
# * BoxPlot
# * Distplot
# * histplot

# %% [markdown]
# **BarPlot**

# %% [markdown]
# **A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.**

# %%
# plot barplt 
??
??
??
??

# run below cell and explore more about barplot

# %%
# generally x-axis categorical, y-axis numerical
# sns.set_style('darkgrid')

# we can both male and female are giving charges
# sns.barplot(df['sex'], df['charges'])
# plt.title('Sex and Charges')
# plt.xlabel('sex')
# plt.ylabel('charges')

# plt.title('sex and charges')

# let provide hue parameters value we, can see smoker is paying more charges tham normal
# sns.barplot(x='sex', y='charges', data=df, hue='smoker')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %%
# use hist plot and it's parameter hue and draw 
??
??
??
??

# %%
# in every region number of smoker people is more than the number of normal people
# Out:
# Text(0, 0.5, 'count')

# %%
# plot
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %%
# smoker and charges
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %%
# region and charges
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %%
# use some paramete of barplot and try to plot
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'charges')

# %% [markdown]
# **Boxplot**

# %% [markdown]
# Boxplot is also used for bivariate analysis.

# %%
# boxplot 
??
??
??
??

# complete this cell and run one by one line of the below cell to explore more about boxplot

# %%
# sns.boxplot(df['sex'], df['charges'])
# plt.title("sex vs charges boxplot")

# sns.set_style('white')
# sns.boxplot(x='sex', y='charges', data = df)


# sns.boxplot(x='sex', y='charges', hue='smoker', data = df)
# plt.title('sex and charges ')
# plt.xlabel('sex')
# plt.ylabel('charges')

# sns.boxplot(y='sex', x='charges', hue='smoker', data = df, order=['male', 'female'])

# you can try many more parameter width, linewidth, whis, filersize, showcap
# Out:
# Text(0, 0.5, 'charges')

# %% [markdown]
# Ans :

# %%
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Charges')

# %% [markdown]
# Ans :

# %%
# use some parameters of box plot 
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Charges')

# %% [markdown]
# In this boxplot we can see smoker with yes values have no outliers.

# %%
??
??
??
??

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'BMI')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# **Distplot**

# %%
# draw distplot and go below and explore more
??
??
??
??

# %%
# sns.distplot(df[df['smoker']=='yes']['bmi'])


# sns.distplot(df[df['smoker']=='yes']['bmi'], kde=False)

# sns.distplot(df[df['smoker']=='yes']['bmi'], hist=False)


# sns.distplot(df[df['smoker']=='yes']['bmi'], hist=False)
# sns.distplot(df[df['smoker']=='no']['bmi'], hist=False)
# plt.title('Density of BMI with smoker')
# plt.xlabel('BMI')
# plt.ylabel('Density')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %% [markdown]
# ## **Categorical vs Categorical**
# * Heatmap, clustermap

# %% [markdown]
# **A heat map is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions.**
#
# in the heatmap parameters are  cmap (color map ), center, vmin , vmax, linewidth, annot   and many more

# %%
# simple heatmap 
array = np.array([[1, 4, 7], [34, 76, 56]])
??

# %%
??

# %%
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
# draw a heatmap
??
??

# run below cell and and explore more about heatmap

# %%
# heatmap with default color palete 
# sns.heatmap(df.corr())
# sns.heatmap(df.corr(), cmap='Blues')
# sns.heatmap(df.corr(), cmap='Blues', annot=True)
# sns.heatmap(df.corr(), cmap='RdBu')
# sns.heatmap(df.corr(), cmap='RdBu', linewidth=1, annot=True)

# %%
crs = pd.crosstab(df['children'], df['sex'])

# %%
# plot heatmap using crs DataFrame , 
??
??

# %%
# Out:
# Text(0.5, 1.0, 'Sex with Children')

# %% [markdown]
# we can tranpose heatmap

# %%
# transpose the crs Dataframe and plot heatmap
??

# %%
# sns.heatmap(crs.T)

# %% [markdown]
# **clustermap() method uses a hierarchical clusters to order data by similarity.**

# %%
# clustermap on crs Data Frame 
??

# %%
# sns.clustermap(pd.crosstab(df['children'], df['sex']), figsize=(6, 6))

# %%
toy_data_dict = {
    'Name': ['Andy', 'Ben', 'Claire', 'David'],
    'Hours_Studied': [10, 20, 12, 28],
    'Score': [15, 20, 16, 25],
    'Street_Address': [11, 24, 18, 9]
}

# %%
toy_data = pd.DataFrame(toy_data_dict)
toy_data.set_index('Name', inplace=True)

toy_data
# Out:
#         Hours_Studied  Score  Street_Address
# Name
# Andy               10     15              11
# Ben                20     20              24
# Claire             12     16              18
# David              28     25               9

# %%
# try to draw this clustermap 
??

# %% [markdown]
# ##Pairplot

# %%
col = ['age', 'bmi', 'charges', 'smoker']
df2 = df[col]
df2.head()
# Out:
#    age     bmi      charges smoker
# 0   19  27.900  16884.92400    yes
# 1   18  33.770   1725.55230     no
# 2   28  33.000   4449.46200     no
# 3   33  22.705  21984.47061     no
# 4   32  28.880   3866.85520     no

# %%
# draw simple pairplot using df2 dataframe
??

# %%
# use hue parameter of pairplt 
??

# %% [markdown]
# #**Exercise Part**
#
#
# **plot and explain every step for the given below Dataset**

# %%
import seaborn as sns

# %%
flight = sns.load_dataset('flights')
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
penguin = sns.load_dataset('penguins').dropna()

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
penguin.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# 5  Adelie  Torgersen            39.3  ...              190.0       3650.0    Male
#
# [5 rows x 7 columns]

# %% [markdown]
# *  Univariate
#   *  Categorical
#   *  Numerical
# *  Bivariate
#   *  Numerical Numerical
#   *  Numerical Categorical
#   *  Categorical Categorical
# *  Multivariate
