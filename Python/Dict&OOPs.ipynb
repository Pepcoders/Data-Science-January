# %% [markdown]
# <a href="https://colab.research.google.com/github/aman5898/Data-Science-January/blob/main/Python/Dict%26OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict1={'Name':"Kunal",
       "Team":"HotDev"}

# %%
dict1
# Out:
# {'Name': 'Kunal', 'Team': 'HotDev'}

# %%
type(dict1)
# Out:
# dict

# %% [markdown]
# Dictionaries are:
# 1. Ordered (After python 3.7)
# 2. Not Indexed
# 3. Mutable (Values can be changed)
# 4. No Duplicate values

# %%
dict2={
    'A':1,
    'C':'Kunal',
    'B':[1,2,3],
    'A':3
}

# %%
dict2
# Out:
# {'A': 3, 'B': [1, 2, 3], 'C': 'Kunal'}

# %%
dict2["A"]
# Out:
# 1

# %%
dict2['C']='Aman'

# %%
dict2
# Out:
# {'A': 1, 'B': [1, 2, 3], 'C': 'Aman'}

# %%
dict2['A']=1

# %%
dict2
# Out:
# {'A': 1, 'B': [1, 2, 3], 'C': 'Aman'}

# %%
type(dict2['B'])
# Out:
# list

# %%
dict2['B'][1]
# Out:
# 2

# %%
dict2
# Out:
# {'A': 3, 'B': [1, 2, 3], 'C': 'Kunal'}

# %%
dict2.keys()
# Out:
# dict_keys(['A', 'C', 'B'])

# %%
dict2.values()
# Out:
# dict_values([3, 'Kunal', [1, 2, 3]])

# %%
for i in dict2.values():
  print(i)
# Out:
# 3
# Kunal
# [1, 2, 3]

# %%
for i,j in dict2.items():
  print(i,j)
# Out:
# A 3
# C Kunal
# B [1, 2, 3]

# %%
for i,j in zip(dict2.values(),dict2.keys()):
  print(i,j)
# Out:
# 3 A
# Kunal C
# [1, 2, 3] B

# %%
dict2.items()
# Out:
# dict_items([('A', 3), ('C', 'Kunal'), ('B', [1, 2, 3])])

# %% [markdown]
# Ques 1:- Make one Dictionary Which has a number 1 to 5 as a key and it's square as a value
#
# dict ={
#     "1":1,
#     '2':4,
#     '3':9,
#     '4':16,
#     '5':25
# }
#
#
# Ques2 :-- Given a dictionary in Python WAP to find the sum of all items in the dictionary

# %%
dict4={val:val*val for val in range(1,6)}

# %%
dict4
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sum1=sum(dict4.values())

# %%
sum1
# Out:
# 55

# %%
dict5=dict4

# %%
dict5
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
dict5=dict()

# %%
dict5
# Out:
# {}

# %%
dict4
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
dict4={}
for i in range(1,7):
  dict4[i]=i*i
dict4
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}

# %% [markdown]
# Exception Handling

# %%
# Out:
# 4

# %%
a=5
b=6
c=a/0

try:
  print("7")
except:
  print("line")

# %% [markdown]
# 1. first try will run
# 2. if try become false then except will run
# 3. if except becomes false or try becomes true else will run
# 4. finally always running

# %%
class Phone:
  a=10
  b=5
  def initilization(ayushi,X):
    ayushi.a=X
    ayushi.d=X
  def video(kunal):
    print("the phone has v call feature")
    print(kunal.a)
    print(kunal.d)

# %%
p1=Phone()

# %%
p1.initilization(20)

# %%
p1.d
# Out:
# 20

# %%
p1.video()
# Out:
# the phone has v call feature
# 20
# 20

# %%
class Phone2:
  def __init__(self,brand,color):
    self.brand=brand
    self.color=color
  def printing(self):
    print("i have "+self.brand+" in color "+self.color)
  def xyz(kunal):
    print("abc")

# %%
class Phone3(Phone2):
  def __init__(self,brand,color,ram,rom):
    super().__init__(brand,color)
    self.ram=ram
    self.rom=rom
  def Printing2(self):
    print("m hu child class")
    print(self.ram)
    print(self.rom)

# %%
p3=Phone3("Samsung","White","16 Gb","256 Gb")

# %%
p3.printing()
# Out:
# i have Samsung in color White

# %%
p3.Printing2()
# Out:
# m hu child class
# 16 Gb
# 256 Gb

# %% [markdown]
# 1. Public Members Everywhere Accesible
# 2. Protected members ==> Derived class and own class
# 3. Private Members ==> only own class

# %%
class A:
  a=10 #Public
  _b=20 #Protected
  __c=30 #Private
  def print_all(self):
    print(self.a)
    print(self._b)
    print(self.__c)

# %%
p1=A()

# %%
p1._b
# Out:
# 20

# %%
p1.print_all()
# Out:
# 10
# 20
# 30

# %%
class B(A):
  def show(self):
    print(self.__c)

# %%
p2=B()

# %%
p2.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-e427480d26ad> in <module>()
# ----> 1 p2.show()
#
# <ipython-input-135-984f4140dda0> in show(self)
#       1 class B(A):
#       2   def show(self):
# ----> 3     print(self.__c)
#
# AttributeError: 'B' object has no attribute '_B__c'

# %%
class C(B):
  def show_me(self):
    print(self._b)

# %%
p3=C()

# %%
p3.show_me()
# Out:
# 20

# %%
def abc():
  pass

# %%
class Name:
  pass
