# %% [markdown]
# <a href="https://colab.research.google.com/github/aman5898/Data-Science-January/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Pepcoding")
# Out:
# Hello Pepcoding

# %%
num = 10

# %%
print(num)
# Out:
# 10

# %%
string = "Pepcoding"

# %%
print(string)
# Out:
# Pepcoding

# %%
print(type(string))
# Out:
# <class 'str'>

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
aaditya = 2.2

# %%
print(type(aaditya))
# Out:
# <class 'float'>

# %%
print(vishant)
# Out:
# 599

# %%
print(type(aaditya),type(num),type(string))
# Out:
# <class 'float'> <class 'int'> <class 'str'>

# %%
vishant = 599

# %%
a,b,c = 10,20,30

# %%
print(a,b,c);
# Out:
# 10 20 30

# %%
a = 55
b='55'

# %%
a=b=c=5

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ##Numbers

# %%
num1 = 100

# %%
num2 = 4.4

# %%
num3 = 5+6j

# %%
print(type(num1),type(num2),type(num3))
# Out:
# <class 'int'> <class 'float'> <class 'complex'>

# %%
print(num1,num2,num3)
# Out:
# 100 4.4 (5+6j)

# %% [markdown]
# ##String

# %%
string = "Pepcoding"

# %%
print(type(string))
# Out:
# <class 'str'>

# %%
print(string[0])
# Out:
# P

# %% [markdown]
# Strings in Python are immutable

# %%
string[0]="A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e44e39c99965> in <module>()
# ----> 1 string[0]="A"
#
# TypeError: 'str' object does not support item assignment

# %%
string = "Nados"

# %%
#Slicing

string[0:3]
# Out:
# 'Pep'

# %%
string[0:]
# Out:
# 'Pepcoding'

# %%
string[1:]
# Out:
# 'epcoding'

# %%
string[:3]
# Out:
# 'Pep'

# %%
string[:]
# Out:
# 'Pepcoding'

# %%
string[0:4:2]
# Out:
# 'Pp'

# %%
string[::2]
# Out:
# 'Ppoig'

# %%
string[7:1:1]
# Out:
# ''

# %%
string[-1]
# Out:
# 'g'

# %%
string[-9:-6]
# Out:
# 'Pep'

# %%
string[8:5:-1]
# Out:
# 'gni'

# %%
string[-3:-9:-1]
# Out:
# 'idocpe'

# %%
string[::-1]
# Out:
# 'gnidocpeP'

# %%
string[:-4:-1]
# Out:
# 'gni'

# %%
len(string)
# Out:
# 9

# %%
string[2:-2:-1]
# Out:
# ''

# %%
string[:4:-1]
# Out:
# 'gnid'

# %%
for ch in string:
  print(ch)
# Out:
# P
# e
# p
# c
# o
# d
# i
# n
# g

# %%
print("Pep",end="")
print("coding")
# Out:
# Pepcoding

# %%
if "coding" in string:
  print("Hello Pepcoding")
# Out:
# Hello Pepcoding

# %%
string.upper()
# Out:
# 'PEPCODING'

# %%
string.lower()
# Out:
# 'pepcoding'

# %% [markdown]
# ##if Else

# %%
if 1>2:
  print("A")
else:
  print("B")
# Out:
# B

# %%
marks = 55

# %%
if marks>90:
  print("A Grade")
elif marks>80:
  print("B Grade")
else:
  print("C Grade")
# Out:
# C Grade

# %%
for i in range(5):
  if i==2:
    break
  print(i*i)
# Out:
# 0
# 1

# %%
i = 0

# %%
while i<5:
  i+=1

# %%
for i in range(5):
  print(str(i)+" Hello")
  if i ==2:
    break
# Out:
# 0 Hello
# 1 Hello
# 2 Hello

# %%
for i in range(5):
  if i ==2:
    continue
  print(str(i)+" Hello")
# Out:
# 0 Hello
# 1 Hello
# 3 Hello
# 4 Hello

# %% [markdown]
# ##List [ ]
#
#
#
# *   Could be hetergeneous
# *   Mutable
# *   Scriptable
# * Ordered

# %%
lst = [1,2,3,"Pepcoding"]

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
lst.append("8")

# %%
lst
# Out:
# [55, 2, 3, 'Pepcoding', '8']

# %%
lst[0]=55

# %%
lst2 = [1,2,3]

lst.append(lst2)

# %%
lst
# Out:
# [55, 2, 3, 'Pepcoding', '8', [1, 2, 3]]

# %%
lst[-1]
# Out:
# [1, 2, 3]

# %%
lst[0:3]
# Out:
# [55, 2, 3]

# %%
lst.insert(1,"DEF")

# %%
lst
# Out:
# [55, 'DEF', 'ABC', 3, 'Pepcoding', '8']

# %%
lst.remove(2)

# %%
print(lst.pop())
# Out:
# [1, 2, 3]

# %%
lst
# Out:
# [55, 'ABC', 3, 'Pepcoding', '8']

# %%
for i in lst:
  print(i)
# Out:
# 55
# ABC
# 3
# Pepcoding
# 8

# %% [markdown]
# ##Tuple ( )
#
#
#
# *   Heterogeneous possible
# *   Immutable
# *   scriptable
# * Ordered

# %%
tup = (1,2,3,"Hello")

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup = (1,2)

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup = (1)

# %%
print(type(tup))
# Out:
# <class 'int'>

# %%
tup = (1,)

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %%
print(tup[0])
# Out:
# 1

# %%
tup[0] = 55
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-a79ca4dc1046> in <module>()
# ----> 1 tup[0] = 55
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in tup:
  print(i)
# Out:
# 1
# 2
# 3
# Hello

# %%
tup.append(55)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-39faf80afa67> in <module>()
# ----> 1 tup.append(55)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ##Set { }
#
#
#
# *   Not Scriptable
# *   Could be Heteregeneous
# * Not Ordered
# * Immutable
# * no Repetitons Allowed

# %%
st = {"Apple","Mango","Pineapple","Apple"}

# %%
st
# Out:
# {'Apple', 'Mango', 'Pineapple'}

# %%
print(type(st))
# Out:
# <class 'set'>

# %%
st[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-028cc1d9138b> in <module>()
# ----> 1 st[0]
#
# TypeError: 'set' object is not subscriptable

# %%
st = {"Apple","Mango","Pineapple",5,6,7}

# %%
st
# Out:
# {5, 6, 7, 'Apple', 'Mango', 'Pineapple'}

# %%
st.add("Orange")

# %%
st
# Out:
# {5, 6, 7, 'Apple', 'Mango', 'Orange', 'Pineapple'}

# %%
st.remove("Apple")

# %%
st
# Out:
# {5, 6, 7, 'Mango', 'Orange', 'Pineapple'}

# %%
st = {1,2,3,["Apple","orange"]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-1484a43af00d> in <module>()
# ----> 1 st = {1,2,3,["Apple","orange"]}
#
# TypeError: unhashable type: 'list'

# %%
for i in st:
  print(i)
# Out:
# 5
# 6
# 7
# Mango
# Pineapple
# Orange

# %%
st.pop()
# Out:
# 5

# %%
st.clear()

# %%
st
# Out:
# set()

# %%
del st

# %%
st
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-235690c2c180> in <module>()
# ----> 1 st
#
# NameError: name 'st' is not defined

# %%
set1 = {1,2,3,4,5}
set2 = {2,5,8,9}

print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
lst = [1,2,3,4,5]

# %%
st = set(lst)

# %%
st
# Out:
# {1, 2, 3, 4, 5}

# %%
lst2 = list(st)

# %%
lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
st.clear()

# %%
st
# Out:
# set()
