# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-January/blob/main/kaggle_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# If you have to download dataset from a competition

! kaggle competitions download titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 22.1MB/s]

# %%
! unzip titanic.zip
# Out:
# Archive:  titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
# if you have to download the data from dataset

! kaggle datasets download guillermonavarr0/data-for-hr-analytics
# Out:
# ...
#   0% 0.00/41.4k [00:00<?, ?B/s]
# 100% 41.4k/41.4k [00:00<00:00, 32.8MB/s]
